# %%
from urllib import request 
import string

class WebWordsFrequency:
    def __init__(self, *l):
        self.urlList = []
        self.words = {}
        for url in l:
            self.addUrl(url)
    
    def addUrl(self, url):
        self.getWords(url)
        self.urlList.append(url)
        
    def removeUrl(self, url):
        if url in self.urlList:
            del self.words[url]
            self.urlList.remove(url)
    
    def listUrls(self):
        for url in self.urlList:
            print (url)
    
    def getWords(self, url):
        self.words[url] = {}
        source = request.urlopen(url).read().decode('utf-8')
        text = ''
        
        while ('<!--' in source):
            # 주석은 <!-- 과 --> 의 쌍으로 나타내어지므로 index 함수를 사용해 주석을 찾아 없앤다
            left = source.index('<!--')
            right = source.index('-->')
            source = source[:left] + source[right+3:]
        
        # Html Entities 제거
        htmlEntities = ['&nbsp;','&quot;','&lt;','&gt;','&amp;']
        for entity in htmlEntities:
            while (entity in source):
                left = source.index(entity)
                right = source.index(entity)
                source = source[:left] + source[right+len(entity):]    
        
        # <script> 태그가 없어질때까지 반복 (javascript 태그)
        while ('<script' in source):
        # <script> 태그 뒤에는 문장이 올 수 있으므로 <script 으로 검사해준다 
        # <script> ~ </script> 사이에 오는 문장은 순수 텍스트가 아니므로 무시한다
            left = source.index('<script')
            right = source.index('</script>')
            source = source[:left] + source[right+9:]
    
        # <style> 태그가 없어질때까지 반복 (css 태그)
        while ('<style' in source):
        # <style> 태그 뒤에는 문장이 올 수 있으므로 <style 으로 검사해준다 
        # <style> ~ </style> 사이에 오는 문장은 순수 텍스트가 아니므로 무시한다
            left = source.index('<style')
            right = source.index('</style>')
            source = source[:left] + source[right+8:] 
    
        # 태그는 < 과 > 의 쌍으로 나타내어지므로 index 함수를 사용해 태그 부분을 찾아 없앤다
        while('<' in source):
            left = source.index('<')
            right = source.index('>')
            text = text + ' ' + source[:left]
            source = source[right+1:]
            
        # 구두 문자 추가
        puncList = list(string.punctuation)
        puncList.extend(['›','’','‘','···','【','】','…','·','»','¢','£','¥','€','®','ⓒ','©']) 
        stopword = "a,about,above,across,after,again,against,all,almost,alone,along,already,also,although,always,among,an,and,another,any,anybody,anyone,anything,anywhere,are,area,areas,around,as,ask,asked,asking,asks,at,away,b,back,backed,backing,backs,be,became,because,become,becomes,been,before,began,behind,being,beings,best,better,between,big,both,but,by,c,came,can,cannot,case,cases,certain,certainly,clear,clearly,come,could,d,did,differ,different,differently,do,does,done,down,down,downed,downing,downs,during,e,each,early,either,end,ended,ending,ends,enough,even,evenly,ever,every,everybody,everyone,everything,everywhere,f,face,faces,fact,facts,far,felt,few,find,finds,first,for,four,from,full,fully,further,furthered,furthering,furthers,g,gave,general,generally,get,gets,give,given,gives,go,going,good,goods,got,great,greater,greatest,group,grouped,grouping,groups,h,had,has,have,having,he,her,here,herself,high,high,high,higher,highest,him,himself,his,how,however,i,if,important,in,interest,interested,interesting,interests,into,is,it,its,itself,j,just,k,keep,keeps,kind,knew,know,known,knows,l,large,largely,last,later,latest,least,less,let,lets,like,likely,long,longer,longest,m,made,make,making,man,many,may,me,member,members,men,might,more,most,mostly,mr,mrs,much,must,my,myself,n,necessary,need,needed,needing,needs,never,new,new,newer,newest,next,no,nobody,non,noone,not,nothing,now,nowhere,number,numbers,o,of,off,often,old,older,oldest,on,once,one,only,open,opened,opening,opens,or,order,ordered,ordering,orders,other,others,our,out,over,p,part,parted,parting,parts,per,perhaps,place,places,point,pointed,pointing,points,possible,present,presented,presenting,presents,problem,problems,put,puts,q,quite,r,rather,really,right,right,room,rooms,s,said,same,saw,say,says,second,seconds,see,seem,seemed,seeming,seems,sees,several,shall,she,should,show,showed,showing,shows,side,sides,since,small,smaller,smallest,so,some,somebody,someone,something,somewhere,state,states,still,still,such,sure,t,take,taken,than,that,the,their,them,then,there,therefore,these,they,thing,things,think,thinks,this,those,though,thought,thoughts,three,through,thus,to,today,together,too,took,toward,turn,turned,turning,turns,two,u,under,until,up,upon,us,use,used,uses,v,very,w,want,wanted,wanting,wants,was,way,ways,we,well,wells,went,were,what,when,where,whether,which,while,who,whole,whose,why,will,with,within,without,work,worked,working,works,would,x,y,year,years,yet,you,young,younger,youngest,your,yours".split(',')
    
        for t in text.split(): # 현재 text에 들어 있는 문장은 순수 텍스트이므로 공백을 기준으로 자름
            for char in puncList: 
                t = t.replace(char, '')
            t = t.lower() # 모든 단어를 대소문자를 구분하지 않고 단어를 저장함
            if len(t) > 0 and not t in stopword:
                if not t in self.words[url].keys():
                    self.words[url][t] = 1
                else:
                    self.words[url][t] += 1

    
    def getWordsFrequency(self):
        if len(self.urlList) == 0:
            return {}
        
        totalWords = {} 
        for url, word in self.words.items():
            for tmp in word.keys():
                if not tmp in totalWords.keys():
                    totalWords[tmp] = word[tmp]
                else:
                    totalWords[tmp] += word[tmp]
        
        return totalWords
    
    
    def getMaxFreqencyWords(self):
        if len(self.urlList) == 0:
            return None
        
        totalWords = self.getWordsFrequency()
        tmp = []
        maxv = 0
        for word, cnt in totalWords.items():
            if cnt > maxv:
                maxv = cnt
            
        for word, cnt in totalWords.items():
            if cnt == maxv:
                tmp.append(word)
        return tmp
    
    
    def searchUrlByWord(self, keyword):
        temp = []
        similarity = {}
        print("\n")
        print ("[ KEYWORD : %s ]" % (keyword))
        print("--------------------------------------\n")
        for i in range(len(self.urlList)):
            
           # print(self.words[self.urlList[i]])
            temp = list(self.words[self.urlList[i]].keys())
            if keyword in temp:
                similarity[self.urlList[i]] = 10 # 기본 유사도를 10으로 줌
            
                print ("URL : " + self.urlList[i])
                print ("키워드 %s 가 포함된 단어 항목입니다\n" % (keyword))
                
                for j in range(len(temp)):
                    if temp[j].find(keyword) != -1 and temp[j] != keyword:
                        print("[word] %s : [similarity] %d" % (temp[j], self.words[self.urlList[i]][temp[j]]))
                        similarity[self.urlList[i]] += self.words[self.urlList[i]][temp[j]]
                    # 입력받은 키워드가 단어 일부일 경우, 해당 단어의 출현 빈도를 더해줌
        
                    elif temp[j] == keyword:
                        print("[word] %s : [similarity] %d" % (temp[j], self.words[self.urlList[i]][temp[j]] + 20))
                        similarity[self.urlList[i]] += (self.words[self.urlList[i]][temp[j]] + 20) 
                    # 입력받은 키워드가 단어와 같을 경우에는, 해당 단어의 출현 빈도에 보너스 점수 20을 더한 것을 더해줌
                print("--------------------------------------")
            else:
                print ("URL : " + self.urlList[i])
                print ("키워드 %s 가 존재하지 않습니다\n" % (keyword))
                print("--------------------------------------")    
            
        
        maxv = 0
        l = []
        for url, count in similarity.items():
            if count > maxv:
                maxv = count;
        # 리스트에 저장
        for url, count in similarity.items():
            if count == maxv:
                l.append(url)
                
        print("=>" , end = ' ')
        return l

# %%
# 인스턴스 생성
w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'http://www.apple.com/')
w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
w3 = WebWordsFrequency()

# add 테스트
w1.addUrl('https://github.com')
w3.addUrl('http://stackoverflow.com')

# remove 테스트
w1.removeUrl('http://www.cnn.com')
w2.removeUrl('http://stackoverflow.com')

# listUrls 테스트
w1.listUrls()
print ()
w2.listUrls()
print ()
w3.listUrls()
print ()
print ()

# getWordsFrequency 테스트
print (w1.getWordsFrequency())
print ()
print ()
print (w2.getWordsFrequency())
print ()
print ()
print (w3.getWordsFrequency())
print ()

# getMaxFreqencyWords 테스트
print (w1.getMaxFreqencyWords())
print ()
print (w2.getMaxFreqencyWords())
print ()
print (w3.getMaxFreqencyWords())
print ()

# searchUrlByWord 테스트
print (w1.searchUrlByWord("news"))
print ()
print (w1.searchUrlByWord('apple'))
# Out:
# http://www.times.com
# http://www.apple.com/
# https://github.com
#
# http://www.cnn.com
# http://www.times.com
#
# http://stackoverflow.com
#
#
# {'york': 8, 'times': 7, 'breaking': 1, 'news': 4, 'world': 9, 'videos': 1, 'continue': 2, 'reading': 2, 'main': 4, 'story': 2, 'sections': 1, 'search': 6, 'skip': 3, 'content': 2, 'site': 6, 'index': 2, 'international': 2, 'canada': 4, 'español': 1, '中文': 1, 'log': 1, 'todays': 1, 'paper': 1, 'politics': 2, 'ny': 2, 'business': 6, 'opinion': 4, 'tech': 2, 'science': 2, 'health': 5, 'sports': 2, 'arts': 2, 'books': 3, 'style': 2, 'food': 2, 'travel': 2, 'magazine': 4, 'real': 3, 'estate': 2, 'video': 2, 'listen': 3, 'daily': 2, 'texas': 2, 'storm': 1, 'processing': 1, 'remembering': 1, 'whitney': 1, 'houston': 1, 'ezra': 1, 'klein': 1, 'crisis': 1, 'normal': 1, 'david': 2, 'wallacewells': 1, 'leah': 1, 'stokes': 1, 'discuss': 2, 'protrump': 1, 'forces': 1, 'pushed': 1, 'lie': 2, 'antifa': 1, 'capitol': 1, 'riot': 1, 'jan': 1, '6': 5, 'supporters': 1, 'former': 1, 'president': 2, 'trump': 4, 'tried': 1, 'rewrite': 1, 'history': 1, 'time': 4, 'social': 2, 'media': 1, 'cable': 1, 'networks': 1, 'halls': 1, 'congress': 1, '12': 4, 'hours': 1, 'false': 1, 'tweet': 1, 'disinformation': 1, 'machine': 2, 'seized': 1, 'served': 1, 'political': 1, 'quickly': 2, 'spread': 1, 'truth': 1, 'live': 2, 'minutes': 3, 'ago': 5, 'washington': 1, 'updates': 2, 'biden': 4, 'immigration': 1, 'trade': 4, 'pandemic': 1, 'mexicos': 1, 'lópez': 1, 'obrador': 1, 'senate': 1, 'bidens': 1, 'stimulus': 1, 'plan': 5, 'midweek': 1, 'elizabeth': 1, 'warren': 1, 'plans': 4, 'introduce': 1, 'wealth': 1, 'tax': 1, 'individuals': 1, 'worth': 1, '50': 2, 'million': 5, 'coronavirus': 4, 'testing': 1, 'slumped': 1, 'complicated': 1, 'californias': 1, 'governor': 1, 'legislature': 1, 'reach': 3, 'agreement': 1, 'schoolreopening': 1, 'thousands': 2, 'farmworkers': 2, 'prioritized': 2, 'vaccinations': 9, 'lines': 1, 'britains': 1, 'covid19': 1, 'war': 1, 'government': 4, 'laid': 1, 'reopening': 1, 'cramped': 1, 'intensive': 1, 'care': 1, 'wards': 1, 'teeming': 1, 'patients': 1, 'doctors': 1, 'near': 2, 'despair': 1, 'battle': 1, 'unrelenting': 1, 'andrew': 1, 'testa': 1, 'vaccine': 10, 'landmark': 1, 'initiative': 1, 'california': 1, 'taking': 2, 'vaccines': 1, 'fields': 2, 'targeting': 1, 'highrisk': 1, 'immigrant': 1, 'force': 1, 'whom': 1, 'undocumented': 1, 'children': 1, 'consuming': 1, 'hand': 1, 'sanitizer': 1, 'poison': 1, 'center': 1, 'data': 2, 'heres': 4, 'safe': 1, 'tracking': 1, 'united': 8, 'feb': 5, '28': 6, '14day': 5, 'change': 8, '50925': 3, '–26': 3, 'deaths': 5, '1129': 3, '–21': 3, 'risk': 2, 'loading': 1, 'vaccinated': 1, '75': 1, 'dose': 1, '15': 2, 'trackers': 6, 'choose': 4, 'own': 4, 'track': 2, 'hospitals': 6, 'global': 14, 'restrictions': 8, 'development': 7, '333883': 1, 'flat': 1, '5832': 1, '–23': 1, 'hot': 2, 'spots': 2, 'worldwide': 2, 'tracker': 2, 'uk': 4, '2307': 1, '–3': 1, '34': 1, '–39': 1, 'bring': 1, 'manufacturing': 1, 'jobs': 2, 'weaken': 1, 'dollar': 1, 'critics': 1, 'strong': 1, 'currency': 1, 'hurts': 1, 'american': 1, 'factory': 1, 'workers': 3, 'imports': 1, 'cheap': 1, 'giving': 1, 'foreign': 1, 'companies': 2, 'advantage': 1, 'labor': 1, 'movement': 2, 'amazon': 3, 'weigh': 1, 'unionization': 1, 'expressed': 1, 'solidarity': 1, 'attempting': 1, 'unionize': 1, '—': 5, 'explicitly': 1, 'cause': 1, 'photos': 1, 'myanmar': 1, 'protests': 1, 'resistance': 1, 'crackdown': 1, 'charges': 3, 'civil': 1, 'disobedience': 1, 'entered': 1, 'month': 2, 'military': 2, 'rulers': 1, 'added': 6, 'daw': 1, 'aung': 1, 'san': 1, 'suu': 1, 'kyi': 1, 'ousted': 1, 'civilian': 1, 'leader': 1, 'teachers': 1, 'protesting': 1, 'mandalay': 1, 'sunday': 1, 'expresident': 1, 'sarkozy': 2, 'found': 5, 'guilty': 1, 'corruption': 2, 'france': 1, 'nicolas': 1, 'sentenced': 1, 'prison': 1, 'influence': 1, 'peddling': 1, 'appealed': 1, 'read': 1, 'lightning': 1, 'strikes': 1, 'twice': 1, 'lost': 1, 'jacob': 3, 'lawrence': 3, 'surfaces': 1, '“i': 2, 'passed': 1, 'kitchen': 1, 'thousand': 1, 'day”': 1, 'paintings': 1, 'owner': 1, 'didnt': 2, 'masterpiece”': 1 ...
#
#
# {'cnn': 19, 'international': 5, 'breaking': 2, 'news': 10, 'world': 11, 'video': 7, 'politics': 5, 'business': 6, 'health': 5, 'entertainment': 3, 'style': 5, 'travel': 5, 'sports': 5, 'videos': 8, 'edition': 2, 'arabic': 2, 'español': 3, 'search': 4, 'menu': 1, 'africa': 4, 'americas': 2, 'asia': 2, 'australia': 2, 'china': 3, 'europe': 2, 'india': 2, 'middle': 2, 'east': 2, 'united': 8, 'kingdom': 2, 'biden': 6, 'presidency': 2, 'elections': 2, 'markets': 2, 'tech': 6, 'media': 6, 'success': 2, 'perspectives': 2, 'food': 6, 'fitness': 2, 'wellness': 2, 'parenting': 3, 'vital': 2, 'signs': 2, 'stars': 3, 'screen': 2, 'binge': 2, 'culture': 2, 'innovate': 2, 'gadget': 2, 'foreseeable': 2, 'future': 2, 'mission': 2, 'ahead': 2, 'upstarts': 2, 'transformed': 2, 'innovative': 2, 'cities': 2, 'arts': 4, 'design': 2, 'fashion': 3, 'architecture': 2, 'luxury': 2, 'beauty': 2, 'destinations': 2, 'drink': 2, 'stay': 2, 'football': 2, 'tennis': 2, 'equestrian': 2, 'golf': 2, 'skiing': 2, 'horse': 2, 'racing': 2, 'motorsport': 2, 'formula': 2, 'esports': 2, 'live': 4, 'tv': 6, 'digital': 2, 'studios': 3, 'films': 2, 'hln': 2, 'schedule': 2, 'az': 2, 'cnnvr': 2, 'features': 4, 'call': 2, 'earth': 2, 'freedom': 2, 'project': 2, 'impact': 2, 'inside': 2, '2': 3, 'degrees': 2, 'heroes': 2, 'weather': 3, 'climate': 2, 'storm': 3, 'tracker': 6, 'wildfire': 2, 'photos': 3, 'longform': 2, 'investigations': 2, 'profiles': 2, 'leadership': 2, 'newsletters': 3, 'follow': 2, 'terms': 3, 'privacy': 2, 'policy': 2, 'accessibility': 2, 'cc': 1, 'adchoices': 1, 'modern': 1, 'slavery': 1, 'act': 1, 'statement': 1, 'advertise': 2, 'store': 1, 'transcripts': 1, 'license': 1, 'footage': 1, 'newsource': 1, 'sitemap': 1, '2021': 2, 'cable': 3, 'network': 2, 'warner': 1, 'company': 2, 'rights': 2, 'reserved': 1, 'sans': 1, '™': 1, '2016': 1, 'york': 8, 'times': 7, 'continue': 2, 'reading': 2, 'main': 2, 'story': 2, 'sections': 1, 'skip': 2, 'content': 1, 'site': 4, 'index': 2, 'canada': 4, '中文': 1, 'log': 1, 'todays': 1, 'paper': 1, 'ny': 2, 'opinion': 4, 'science': 2, 'books': 2, 'magazine': 4, 'real': 3, 'estate': 2, 'listen': 3, 'daily': 1, 'texas': 2, 'processing': 1, 'remembering': 1, 'whitney': 1, 'houston': 1, 'ezra': 1, 'klein': 1, 'crisis': 1, 'normal': 1, 'david': 2, 'wallacewells': 1, 'leah': 1, 'stokes': 1, 'discuss': 2, 'protrump': 1, 'forces': 1, 'pushed': 1, 'lie': 2, 'antifa': 1, 'capitol': 1, 'riot': 1, 'jan': 1, '6': 2, 'supporters': 1, 'former': 1, 'president': 2, 'trump': 4, 'tried': 1, 'rewrite': 1, 'history': 1, 'time': 3, 'social': 1, 'networks': 1, 'halls': 1, 'congress': 1, '12': 1, 'hours': 1, 'false': 1, 'tweet': 1, 'disinformation': 1, 'machine': 1, 'seized': 1, 'served': 1, 'political': 1, 'quickly': 2, 'spread': 1, 'truth': 1, 'minutes': 1, 'ago': 1, 'washington': 1, 'updates': 2, 'immigration': 1, 'trade': 1, 'pandemic': 1, 'mexicos': 1, 'lópez': 1, 'obrador': 1, 'senate': 1, 'bidens': 1, 'stimulus': 1, 'plan': 2, 'midweek': 1, 'elizabeth': 1, 'warren': 1, 'plans': 2, 'introduce': 1, 'wealth': 1, 'tax': 1, 'individuals': 1, 'worth': 1, '50': 1, 'million': 1, 'coronavirus': 4, 'testing': 1, 'slumped': 1, 'complicated': 1, 'californias': 1, 'governor': 1, 'legislature': 1, 'reach': 1, 'agreement': 1, 'schoolreopening': 1, 'thousands': 2, 'farmworkers': 2, 'prioritized': 2, 'vaccinations': 9, 'lines': 1, 'britains': 1, 'covid19': 1, 'war': 1, 'government': 2, 'laid': 1, 'reopening': 1, 'cramped': 1, 'intensive': 1, 'care': 1, 'wards': 1, 'teeming': 1, 'patients': 1, 'doctors': 1, 'near': 1, 'despair': 1, 'battle': 1, 'unrelenting': 1, 'andrew': 1, 'testa': 1, 'vaccine': 10, 'landmark': 1, 'initiative': 1, 'california': 1, 'taking': 2, 'vaccines': 1, 'fields': 1, 'targeting': 1, 'highrisk': 1, 'immigrant': 1, 'force': 1, 'whom': 1, 'undocumented': 1, 'children': 1, 'consuming': 1, 'hand': 1, 'sanitizer': 1, 'poison': 1, 'center': 1, 'data': 1, 'heres': 4, 'safe': 1, 'tracking': 1, 'feb': 5, '28': 5, '14day': 5, 'change': 5, '50925': ...
#
#
# {'stack': 30, 'overflow': 22, 'developers': 13, 'learn': 5, 'share': 9, 'build': 4, 'careers': 1, 'products': 4, 'teams': 10, 'public': 3, 'questions': 10, 'answers': 7, 'technologists': 3, 'private': 8, 'knowledge': 15, 'coworkers': 3, 'jobs': 10, 'programming': 1, 'related': 1, 'technical': 4, 'career': 2, 'opportunities': 2, 'talent': 6, 'recruit': 1, 'tech': 1, 'employer': 2, 'brand': 2, 'advertising': 4, 'reach': 3, 'worldwide': 2, 'company': 3, 'spopovershow': 1, 'dataspopoverplacementbottomstart': 1, 'loadingx2026': 1, 'log': 2, 'sign': 3, 'current': 1, 'community': 5, 'help': 8, 'chat': 2, 'meta': 2, 'communities': 2, 'customize': 1, 'list': 1, 'exchange': 5, 'blog': 2, 'home': 2, 'tags': 3, 'users': 3, 'job': 5, 'companies': 1, 'whatx2019s': 1, 'create': 3, 'team': 3, 'qa': 6, 'connect': 2, 'single': 3, 'location': 2, 'structured': 1, 'easy': 1, 'search': 2, 'x3c3': 1, 'people': 2, 'code': 4, 'empower': 1, 'solutions': 2, 'enable': 1, 'productivity': 1, 'growth': 1, 'discovery': 2, 'businesses': 2, 'codes': 1, 'toughest': 1, 'coding': 2, 'dream': 1, '165': 1, 'million': 2, 'sharing': 1, 'account': 2, 'browse': 6, 'level': 2, 'privately': 2, 'using': 3, 'flagship': 1, 'engine': 1, 'try': 1, 'free': 3, 'quality': 2, 'listings': 1, 'roles': 2, 'based': 2, 'title': 1, 'technology': 4, 'salary': 3, 'mission': 1, 'write': 3, 'script': 2, 'future': 2, 'means': 1, 'helping': 1, 'hire': 2, 'skilled': 1, 'business': 3, 'providing': 1, 'tools': 1, 'effectively': 1, 'quickly': 1, 'internal': 1, 'perfect': 1, 'candidate': 1, 'growing': 1, 'accelerate': 1, 'services': 1, 'platform': 1, 'unlock': 1, 'siloed': 1, 'wikis': 1, 'messages': 1, 'formal': 1, 'documentation': 1, 'management': 1, 'arent': 1, 'effective': 1, 'question': 5, 'answer': 6, 'format': 1, 'proven': 1, 'approach': 1, 'accessing': 1, 'information': 5, 'time': 1, 'basic': 1, 'base': 3, '6': 1, 'usd': 3, '7': 1, 'teammate': 2, 'month': 2, 'monthly': 1, 'yearly': 1, '30': 1, 'day': 1, 'trial': 2, 'chatops': 3, 'integrations': 3, 'slack': 1, 'microsoft': 1, 'own': 2, 'space': 1, 'hosted': 1, 'stackoverflowcom': 1, 'searchable': 2, 'archive': 1, 'start': 2, 'sso': 2, 'premium': 2, 'features': 2, '12': 1, 'longform': 1, 'articles': 1, 'additional': 1, 'x2014': 2, 'jira': 2, 'github': 2, 'okta': 2, 'content': 2, 'collections': 1, 'signon': 2, 'saml': 2, 'reporting': 1, 'analytics': 1, 'priority': 2, 'customer': 2, 'support': 3, '995': 2, 'uptime': 2, 'started': 1, 'enterprise': 2, 'standalone': 1, 'enhanced': 1, 'security': 2, 'flexible': 2, 'hosting': 2, 'custom': 1, 'pricing': 1, 'talk': 1, 'plus': 1, 'unlimited': 1, 'instance': 1, 'ad': 1, 'options': 1, 'cloud': 1, 'onpremises': 1, 'robust': 1, 'read': 2, 'api': 2, 'success': 1, 'building': 1, 'representative': 1, 'sla': 1, 'request': 1, 'demo': 1, 'leader': 1, 'winter': 1, '2021': 2, 'love': 1, 'expand': 1, 'hiring': 1, 'strategy': 1, 'promote': 1, 'highlight': 1, 'relevant': 1, '100': 1, 'worlds': 1, 'largest': 1, 'resource': 1, 'increase': 1, 'awareness': 2, 'showcase': 1, 'product': 1, 'service': 2, 'overflows': 1, 'network': 3, 'sites': 2, 'vote': 1, 'tag': 1, 'accept': 2, 'recognized': 1, 'publicly': 1, '170': 1, 'upvoting': 1, 'helps': 1, 'exceptional': 1, 'rise': 1, 'top': 1, 'bring': 1, 'useful': 1, 'responses': 1, 'world': 1, 'solved': 1, 'benefit': 1, 'valuable': 1, 'reputation': 1, 'system': 1, 'rewards': 1, 'experienced': 1, 'contribution': 1, 'activity': 1, 'grow': 1, 'answered': 1, 'youre': 1, 'beginning': 1, 'javascript': 2, 'react': 1, 'professional': 1, 'source': 1, 'project': 2, 'following': 1, 'answering': 1, 'newcomer': 1, 'empowering': 1, 'experts': 1, 'curl': 1, 'creators': 1, 'story': 2, 'acquire': 1, 'gain': 1, 'insights': 1, 'audience': 1, 'profile': 1, 'expertise': 1, 'credentials': 1, 'move': 1, 'developer': 2, 'looking': 1, 'visa': 1, 'sponsorship': 1, 'remotefriendly': 1, 'view': 1, 'directory': 1, 'calculator': 1, 'mobile': 1, 'press': 1, 'legal': 1, 'privacy': 1, 'policy': 1, 'terms': 1, 'c ...
#
# ['apple']
#
# ['cnn']
#
# ['stack']
#
#
#
# [ KEYWORD : news ]
# --------------------------------------
#
# URL : http://www.times.com
# 키워드 news 가 포함된 단어 항목입니다
#
# [word] news : [similarity] 23
# --------------------------------------
# URL : http://www.apple.com/
# 키워드 news 가 포함된 단어 항목입니다
#
# [word] renews : [similarity] 3
# [word] news : [similarity] 21
# [word] newsroom : [similarity] 1
# --------------------------------------
# URL : https://github.com
# 키워드 news 가 존재하지 않습니다
#
# --------------------------------------
# => ['http://www.apple.com/']
#
#
#
# [ KEYWORD : apple ]
# --------------------------------------
#
# URL : http://www.times.com
# 키워드 apple 가 존재하지 않습니다
#
# --------------------------------------
# URL : http://www.apple.com/
# 키워드 apple 가 포함된 단어 항목입니다
#
# [word] apple : [similarity] 77
# [word] applecom : [similarity] 1
# [word] 1800myapple : [similarity] 1
# --------------------------------------
# URL : https://github.com
# 키워드 apple 가 포함된 단어 항목입니다
#
# [word] apple : [similarity] 21
# --------------------------------------
# => ['http://www.apple.com/']

# %%
class OrderedWebWordsFrequency(WebWordsFrequency):
    def __init__(self, *l):
        WebWordsFrequency.__init__(self, *l)
    
    def getWordsFrequency(self, reverse = False):
        totalWords = WebWordsFrequency.getWordsFrequency(self)
        
        # 기본적으로 내림차순 정렬 후 반환
        li = []
        temp = list(totalWords.values())
        temp.sort(reverse = not reverse)
        for value in temp:
            for key in totalWords.keys():
                if value == totalWords[key]:
                    li.append((key, totalWords[key]))
                    del totalWords[key]
                    break
        return li

# %%
w4 = OrderedWebWordsFrequency('http://www.times.com', 'http://edition.cnn.com', 'https://github.com')
print(w4.getWordsFrequency())
print()
print()
print(w4.getWordsFrequency(reverse = True))
# Out:
# [('github', 39), ('rarr', 28), ('code', 20), ('cnn', 19), ('world', 15), ('global', 12), ('news', 10), ('vaccine', 10), ('actions', 10), ('vaccinations', 9), ('york', 8), ('videos', 8), ('search', 8), ('united', 8), ('change', 8), ('features', 8), ('learn', 8), ('↵', 8), ('build', 8), ('pull', 8), ('times', 7), ('video', 7), ('development', 7), ('review', 7), ('software', 7), ('security', 7), ('sign', 7), ('business', 6), ('tech', 6), ('food', 6), ('media', 6), ('biden', 6), ('28', 6), ('trackers', 6), ('hospitals', 6), ('restrictions', 6), ('tracker', 6), ('added', 6), ('tv', 6), ('octocatclassifier', 6), ('requests', 6), ('merge', 6), ('site', 5), ('international', 5), ('politics', 5), ('health', 5), ('sports', 5), ('style', 5), ('travel', 5), ('ago', 5), ('million', 5), ('feb', 5), ('14day', 5), ('deaths', 5), ('—', 5), ('found', 5), ('contact', 5), ('project', 5), ('2', 5), ('codespaces', 5), ('packages', 5), ('source', 5), ('community', 5), ('jump', 5), ('developers', 5), ('git', 5), ('main', 4), ('canada', 4), ('opinion', 4), ('arts', 4), ('magazine', 4), ('trump', 4), ('time', 4), ('live', 4), ('plans', 4), ('coronavirus', 4), ('heres', 4), ('own', 4), ('uk', 4), ('images', 4), ('stars', 4), ('learning', 4), ('home', 4), ('company', 4), ('privacy', 4), ('terms', 4), ('africa', 4), ('support', 4), ('team', 4), ('platform', 4), ('3', 4), ('repositories', 4), ('octocat', 4), ('→', 4), ('create', 4), ('write', 4), ('npm', 4), ('vulnerabilities', 4), ('available', 4), ('desktop', 4), ('macos', 4), ('windows', 4), ('started', 4), ('skip', 3), ('español', 3), ('real', 3), ('listen', 3), ('storm', 3), ('6', 3), ('cable', 3), ('minutes', 3), ('reach', 3), ('50925', 3), ('–26', 3), ('1129', 3), ('–21', 3), ('workers', 3), ('amazon', 3), ('photos', 3), ('charges', 3), ('jacob', 3), ('lawrence', 3), ('via', 3), ('golden', 3), ('globes', 3), ('studios', 3), ('fashion', 3), ('china', 3), ('private', 3), ('weather', 3), ('parenting', 3), ('2021', 3), ('help', 3), ('entertainment', 3), ('future', 3), ('stay', 3), ('impact', 3), ('newsletters', 3), ('builds', 3), ('mobile', 3), ('sponsors', 3), ('enterprise', 3), ('explore', 3), ('sales', 3), ('largest', 3), ('built', 3), ('secure', 3), ('cloud', 3), ('readmemd', 3), ('✓', 3), ('created', 3), ('package', 3), ('projects', 3), ('run', 3), ('javascript', 3), ('browse', 3), ('check', 3), ('cli', 3), ('linux', 3), ('developer', 3), ('automation', 3), ('oauth', 3), ('sponsoring', 3), ('days', 3), ('flutter', 3), ('ansible', 3), ('breaking', 2), ('continue', 2), ('reading', 2), ('story', 2), ('content', 2), ('index', 2), ('ny', 2), ('science', 2), ('books', 2), ('estate', 2), ('texas', 2), ('david', 2), ('discuss', 2), ('lie', 2), ('president', 2), ('social', 2), ('12', 2), ('machine', 2), ('quickly', 2), ('10', 2), ('updates', 2), ('plan', 2), ('50', 2), ('thousands', 2), ('farmworkers', 2), ('prioritized', 2), ('government', 2), ('taking', 2), ('fields', 2), ('data', 2), ('risk', 2), ('15', 2), ('choose', 2), ('track', 2), ('hot', 2), ('spots', 2), ('worldwide', 2), ('jobs', 2), ('companies', 2), ('movement', 2), ('month', 2), ('sarkozy', 2), ('corruption', 2), ('“i', 2), ('didnt', 2), ('rights', 2), ('moving', 2), ('ap', 2), ('getty', 2), ('nbc', 2), ('lot', 2), ('complete', 2), ('20', 2), ('thanks', 2), ('accessibility', 2), ('advertise', 2), ('studio', 2), ('policy', 2), ('service', 2), ('map', 2), ('edition', 2), ('arabic', 2), ('americas', 2), ('asia', 2), ('australia', 2), ('europe', 2), ('india', 2), ('middle', 2), ('east', 2), ('kingdom', 2), ('presidency', 2), ('elections', 2), ('markets', 2), ('success', 2), ('perspectives', 2), ('fitness', 2), ('wellness', 2), ('vital', 2), ('signs', 2), ('screen', 2), ('binge', 2), ('culture', 2), ('innovate', 2), ('gadget', 2), ('foreseeable', 2), ('mission', 2), ('ahead', 2), ('upstarts', 2), ('transformed', 2), ('innovative', 2), ('cities', 2), ('design', 2), ('architecture', 2), ('luxury', 2), ('beauty', 2), ('destinations', 2), ('drink', 2), ...
#
#
# [('sections', 1), ('中文', 1), ('log', 1), ('todays', 1), ('paper', 1), ('daily', 1), ('processing', 1), ('remembering', 1), ('whitney', 1), ('houston', 1), ('ezra', 1), ('klein', 1), ('crisis', 1), ('normal', 1), ('wallacewells', 1), ('leah', 1), ('stokes', 1), ('protrump', 1), ('forces', 1), ('pushed', 1), ('antifa', 1), ('capitol', 1), ('riot', 1), ('jan', 1), ('supporters', 1), ('former', 1), ('tried', 1), ('rewrite', 1), ('history', 1), ('networks', 1), ('halls', 1), ('congress', 1), ('hours', 1), ('false', 1), ('tweet', 1), ('disinformation', 1), ('seized', 1), ('served', 1), ('political', 1), ('spread', 1), ('truth', 1), ('washington', 1), ('immigration', 1), ('trade', 1), ('pandemic', 1), ('mexicos', 1), ('lópez', 1), ('obrador', 1), ('senate', 1), ('bidens', 1), ('stimulus', 1), ('midweek', 1), ('elizabeth', 1), ('warren', 1), ('introduce', 1), ('wealth', 1), ('tax', 1), ('individuals', 1), ('worth', 1), ('testing', 1), ('slumped', 1), ('complicated', 1), ('californias', 1), ('governor', 1), ('legislature', 1), ('agreement', 1), ('schoolreopening', 1), ('lines', 1), ('britains', 1), ('covid19', 1), ('war', 1), ('laid', 1), ('reopening', 1), ('cramped', 1), ('intensive', 1), ('care', 1), ('wards', 1), ('teeming', 1), ('patients', 1), ('doctors', 1), ('near', 1), ('despair', 1), ('battle', 1), ('unrelenting', 1), ('andrew', 1), ('testa', 1), ('landmark', 1), ('initiative', 1), ('california', 1), ('vaccines', 1), ('targeting', 1), ('highrisk', 1), ('immigrant', 1), ('force', 1), ('whom', 1), ('undocumented', 1), ('children', 1), ('consuming', 1), ('hand', 1), ('sanitizer', 1), ('poison', 1), ('center', 1), ('safe', 1), ('tracking', 1), ('loading', 1), ('vaccinated', 1), ('75', 1), ('dose', 1), ('333883', 1), ('flat', 1), ('5832', 1), ('–23', 1), ('2307', 1), ('–3', 1), ('34', 1), ('–39', 1), ('bring', 1), ('manufacturing', 1), ('weaken', 1), ('dollar', 1), ('critics', 1), ('strong', 1), ('currency', 1), ('hurts', 1), ('american', 1), ('factory', 1), ('imports', 1), ('cheap', 1), ('giving', 1), ('foreign', 1), ('advantage', 1), ('labor', 1), ('weigh', 1), ('unionization', 1), ('expressed', 1), ('solidarity', 1), ('attempting', 1), ('unionize', 1), ('explicitly', 1), ('cause', 1), ('myanmar', 1), ('protests', 1), ('resistance', 1), ('crackdown', 1), ('civil', 1), ('disobedience', 1), ('entered', 1), ('military', 1), ('rulers', 1), ('daw', 1), ('aung', 1), ('san', 1), ('suu', 1), ('kyi', 1), ('ousted', 1), ('civilian', 1), ('leader', 1), ('teachers', 1), ('protesting', 1), ('mandalay', 1), ('sunday', 1), ('expresident', 1), ('guilty', 1), ('france', 1), ('nicolas', 1), ('sentenced', 1), ('prison', 1), ('influence', 1), ('peddling', 1), ('appealed', 1), ('read', 1), ('lightning', 1), ('strikes', 1), ('twice', 1), ('lost', 1), ('surfaces', 1), ('passed', 1), ('kitchen', 1), ('thousand', 1), ('day”', 1), ('paintings', 1), ('owner', 1), ('masterpiece”', 1), ('longlost', 1), ('panel', 1), ('“immigrants', 1), ('admitted', 1), ('countries', 1), ('18201840—115773”', 1), ('hung', 1), ('residential', 1), ('wall', 1), ('manhattan', 1), ('decades', 1), ('gwendolyn', 1), ('knight', 1), ('foundation', 1), ('seattleartists', 1), ('society', 1), ('ars', 1), ('peabody', 1), ('essex', 1), ('museum', 1), ('worst', 1), ('amid', 1), ('deeply', 1), ('moments', 1), ('technical', 1), ('difficulties', 1), ('strange', 1), ('sight', 1), ('longdistance', 1), ('hosts', 1), ('pretending', 1), ('stage', 1), ('leenetflix', 1), ('peter', 1), ('kramerafp', 1), ('christopher', 1), ('polkafp', 1), ('charllie', 1), ('graynetflix', 1), ('reuters', 1), ('hello', 1), ('red', 1), ('carpet', 1), ('missed', 1), ('ok', 1), ('virtual', 1), ('watching', 1), ('dress', 1), ('actually', 1), ('fun', 1), ('critic', 1), ('writes', 1), ('beset', 1), ('onscreen', 1), ('offscreen', 1), ('boozy', 1), ('escape', 1), ('list', 1), ('winners', 1), ('gail', 1), ('collins', 1), ('bret', 1), ('stephens', 1), ('looks', 1), ('awful', 1), ('2020', 1), ('daniel', 1), ('mccarthy', 1), ('holds ...

# %%
class OrderedWebWordsFrequency(WebWordsFrequency):
    def __init__(self, *l):
        WebWordsFrequency.__init__(self, *l)
    
    def getWordsFrequency(self, reverse = False):
        totalWords = WebWordsFrequency.getWordsFrequency(self)
        
        # 기본적으로 내림차순 정렬 후 반환
        li = []
        temp = list(totalWords.values())
        temp.sort(reverse = not reverse)
        for value in temp:
            for key in totalWords.keys():
                if value == totalWords[key]:
                    li.append((key, totalWords[key]))
                    del totalWords[key]
                    break
        return li
    
    def __iter__(self):
        self.i = -1
        self.tmpFrequency = self.getWordsFrequency()
        return self
    
    def __next__(self):
        self.i += 1
        if len(self.tmpFrequency) <= self.i:
            raise StopIteration
            
        return self.tmpFrequency[self.i]

# %%
w4 = OrderedWebWordsFrequency('http://www.times.com')
for i in w4:
    print(i)
# Out:
# ('global', 12)
# ('vaccine', 10)
# ('vaccinations', 9)
# ('york', 8)
# ('times', 7)
# ('united', 6)
# ('trackers', 6)
# ('hospitals', 6)
# ('restrictions', 6)
# ('development', 6)
# ('world', 5)
# ('feb', 5)
# ('28', 5)
# ('14day', 5)
# ('change', 5)
# ('deaths', 5)
# ('site', 4)
# ('canada', 4)
# ('opinion', 4)
# ('magazine', 4)
# ('trump', 4)
# ('biden', 4)
# ('coronavirus', 4)
# ('heres', 4)
# ('uk', 4)
# ('—', 4)
# ('news', 3)
# ('business', 3)
# ('real', 3)
# ('listen', 3)
# ('time', 3)
# ('50925', 3)
# ('–26', 3)
# ('1129', 3)
# ('–21', 3)
# ('own', 3)
# ('workers', 3)
# ('amazon', 3)
# ('charges', 3)
# ('jacob', 3)
# ('lawrence', 3)
# ('via', 3)
# ('golden', 3)
# ('globes', 3)
# ('continue', 2)
# ('reading', 2)
# ('main', 2)
# ('story', 2)
# ('skip', 2)
# ('index', 2)
# ('international', 2)
# ('politics', 2)
# ('ny', 2)
# ('tech', 2)
# ('science', 2)
# ('health', 2)
# ('sports', 2)
# ('arts', 2)
# ('books', 2)
# ('style', 2)
# ('food', 2)
# ('travel', 2)
# ('estate', 2)
# ('video', 2)
# ('texas', 2)
# ('david', 2)
# ('discuss', 2)
# ('lie', 2)
# ('6', 2)
# ('president', 2)
# ('quickly', 2)
# ('live', 2)
# ('updates', 2)
# ('plan', 2)
# ('plans', 2)
# ('thousands', 2)
# ('farmworkers', 2)
# ('prioritized', 2)
# ('government', 2)
# ('taking', 2)
# ('choose', 2)
# ('track', 2)
# ('hot', 2)
# ('spots', 2)
# ('worldwide', 2)
# ('tracker', 2)
# ('movement', 2)
# ('sarkozy', 2)
# ('corruption', 2)
# ('“i', 2)
# ('didnt', 2)
# ('ap', 2)
# ('getty', 2)
# ('images', 2)
# ('nbc', 2)
# ('lot', 2)
# ('terms', 2)
# ('breaking', 1)
# ('videos', 1)
# ('sections', 1)
# ('search', 1)
# ('content', 1)
# ('español', 1)
# ('中文', 1)
# ('log', 1)
# ('todays', 1)
# ('paper', 1)
# ('daily', 1)
# ('storm', 1)
# ('processing', 1)
# ('remembering', 1)
# ('whitney', 1)
# ('houston', 1)
# ('ezra', 1)
# ('klein', 1)
# ('crisis', 1)
# ('normal', 1)
# ('wallacewells', 1)
# ('leah', 1)
# ('stokes', 1)
# ('protrump', 1)
# ('forces', 1)
# ('pushed', 1)
# ('antifa', 1)
# ('capitol', 1)
# ('riot', 1)
# ('jan', 1)
# ('supporters', 1)
# ('former', 1)
# ('tried', 1)
# ('rewrite', 1)
# ('history', 1)
# ('social', 1)
# ('media', 1)
# ('cable', 1)
# ('networks', 1)
# ('halls', 1)
# ('congress', 1)
# ('12', 1)
# ('hours', 1)
# ('false', 1)
# ('tweet', 1)
# ('disinformation', 1)
# ('machine', 1)
# ('seized', 1)
# ('served', 1)
# ('political', 1)
# ('spread', 1)
# ('truth', 1)
# ('2', 1)
# ('minutes', 1)
# ('ago', 1)
# ('washington', 1)
# ('immigration', 1)
# ('trade', 1)
# ('pandemic', 1)
# ('mexicos', 1)
# ('lópez', 1)
# ('obrador', 1)
# ('senate', 1)
# ('bidens', 1)
# ('stimulus', 1)
# ('midweek', 1)
# ('elizabeth', 1)
# ('warren', 1)
# ('introduce', 1)
# ('wealth', 1)
# ('tax', 1)
# ('individuals', 1)
# ('worth', 1)
# ('50', 1)
# ('million', 1)
# ('testing', 1)
# ('slumped', 1)
# ('complicated', 1)
# ('californias', 1)
# ('governor', 1)
# ('legislature', 1)
# ('reach', 1)
# ('agreement', 1)
# ('schoolreopening', 1)
# ('lines', 1)
# ('britains', 1)
# ('covid19', 1)
# ('war', 1)
# ('laid', 1)
# ('reopening', 1)
# ('cramped', 1)
# ('intensive', 1)
# ('care', 1)
# ('wards', 1)
# ('teeming', 1)
# ('patients', 1)
# ('doctors', 1)
# ('near', 1)
# ('despair', 1)
# ('battle', 1)
# ('unrelenting', 1)
# ('andrew', 1)
# ('testa', 1)
# ('landmark', 1)
# ('initiative', 1)
# ('california', 1)
# ('vaccines', 1)
# ('fields', 1)
# ('targeting', 1)
# ('highrisk', 1)
# ('immigrant', 1)
# ('force', 1)
# ('whom', 1)
# ('undocumented', 1)
# ('children', 1)
# ('consuming', 1)
# ('hand', 1)
# ('sanitizer', 1)
# ('poison', 1)
# ('center', 1)
# ('data', 1)
# ('safe', 1)
# ('tracking', 1)
# ('risk', 1)
# ('loading', 1)
# ('vaccinated', 1)
# ('75', 1)
# ('dose', 1)
# ('15', 1)
# ('333883', 1)
# ('flat', 1)
# ('5832', 1)
# ('–23', 1)
# ('2307', 1)
# ('–3', 1)
# ('34', 1)
# ('–39', 1)
# ('bring', 1)
# ('manufacturing', 1)
# ('jobs', 1)
# ('weaken', 1)
# ('dollar', 1)
# ('critics', 1)
# ('strong', 1)
# ('currency', 1)
# ('hurts', 1)
# ('american', 1)
# ('factory', 1)
# ('imports', 1)
# ('cheap', 1)
# ('giving', 1)
# ('foreign', 1)
# ('companies', 1)
# ('advantage', 1)
# ('labor', 1)
# ('weigh', 1)
# ('unionization', 1)
# ('expressed', 1)
# ('solidarity', 1)
# ('attempting', 1)
# ('unionize', 1)
# ('explicitly', 1)
# ('cause', 1)
# ('photos', 1)
# ('myanmar', 1)
# ('protests', 1)
# ('resistance', 1)
# ('crackdown', 1)
# ('civil', 1)
# ('disobedience', 1)
# ('entered', 1)
# ('month', 1)
# ('military', 1)
# ('rulers', 1)
# ('added', 1)
# ('daw', 1)
# ('aung', 1)
# ('san', 1)
# ('suu', 1)
# ('kyi', 1)
# ('ousted', 1)
# ('civilian', 1)
# ('leader', 1)
# ('teachers', 1)
# ('protesting', 1)
# ('mandalay', 1)
# ('sunday', 1)
# ('expresident', 1)
# ('found', 1)
# ('guilty', 1)
# ('france', 1)
# ('nicolas', 1)
# ('sentenced', 1)
# ('prison', 1)
# ('influence', 1)
# ('peddling', 1)
# ('appealed', 1)
# ('read', 1)
# ('lightning', 1)
# ('strikes', 1)
# ('twice', 1)
# ('lost', 1)
# ('surfaces', 1)
# ('passed', 1)
# ('kitchen', 1)
# ('thousand', 1)
# ('day”', 1)
# ('paintings', 1)
# ('owner', 1)
# ('masterpiece”', 1)
# ('longlost', 1)
# ('panel', 1)
# ('“immigrants', 1)
# ('admitted', 1)
# ('countries', 1)
# ('18201840—115773”', 1)
# ('hung', 1)
# ('residential', 1)
# ('wall', 1)
# ('manhattan', 1)
# ('decades', 1)
# ('gwendolyn', 1)
# ('knight', 1)
# ('foundation', 1)
# ('seattleartists', 1)
# ('rights', 1)
# ('society', 1)
# ('ars', 1)
# ('peabody', 1)
# ('essex', 1)
# ('museum', 1)
# ('worst', 1)
# ('amid', 1)
# ('deeply', 1)
# ('moving', 1)
# ('moments', 1)
# ('technical', 1)
# ('difficulties', 1)
# ('strange', 1)
# ('sight', 1)
# ('longdistance', 1)
# ('hosts', 1)
# ('pretending', 1)
# ('stage', 1)
# ('leenetflix', 1)
# ('peter', 1)
# ('kramerafp', 1)
# ('christopher', 1)
# ('polkafp', 1)
# ('charllie', 1)
# ('graynetflix', 1)
# ('reuters', 1)
# ('studios', 1)
# ('hello', 1)
# ('red', 1)
# ('carpet', 1)
# ('missed', 1)
# ('ok', 1)
# ('virtual', 1)
# ('watching', 1)
# ('stars', 1)
# ('dress', 1)
# ('actually', 1)
# ('fun', 1)
# ('fashion', 1)
# ('critic', 1)
# ('writes', 1)
# ('review', 1)
# ('beset', 1)
# ('onscreen', 1)
# ('offscreen', 1)
# ('boozy', 1)
# ('escape', 1)
# ('complete', 1)
# ('list', 1)
# ('winners', 1)
# ('gail', 1)
# ('collins', 1)
# ('bret', 1)
# ('stephens', 1)
# ('20', 1)
# ('looks', 1)
# ('awful', 1)
# ('2020', 1)
# ('daniel', 1)
# ('mccarthy', 1)
# ('holds', 1)
# ('grip', 1)
# ('gop', 1)
# ('republicans', 1)
# ('embrace', 1)
# ('power', 1)
# ('expresidents', 1)
# ('agenda', 1)
# ('galvanize', 1)
# ('voters', 1)
# ('drive', 1)
# ('turnout', 1)
# ('yizheng', 1)
# ('lian', 1)
# ('china', 1)
# ('hong', 1)
# ('kong', 1)
# ('hard', 1)
# ('charles', 1)
# ('blow', 1)
# ('voter', 1)
# ('suppression', 1)
# ('grand', 1)
# ('larceny', 1)
# ('kara', 1)
# ('swisher', 1)
# ('job', 1)
# ('gofundme', 1)
# ('vanessa', 1)
# ('barbara', 1)
# ('brazil', 1)
# ('brilliant', 1)
# ('wrong', 1)
# ('editorial', 1)
# ('board', 1)
# ('era', 1)
# ('diplomacy', 1)
# ('william', 1)
# ('cohan', 1)
# ('private', 1)
# ('equity', 1)
# ('party', 1)
# ('esau', 1)
# ('mccaulley', 1)
# ('months', 1)
# ('solo', 1)
# ('parent', 1)
# ('ross', 1)
# ('douthat', 1)
# ('twilight', 1)
# ('antitrump', 1)
# ('idols', 1)
# ('maureen', 1)
# ('dowd', 1)
# ('supply', 1)
# ('editors', 1)
# ('picks', 1)
# ('surfs', 1)
# ('temperature', 1)
# ('isnt', 1)
# ('growing', 1)
# ('surfers', 1)
# ('lakes', 1)
# ('weather', 1)
# ('below', 1)
# ('freezing', 1)
# ('drugstore', 1)
# ('nearly', 1)
# ('storied', 1)
# ('city', 1)
# ('co', 1)
# ('bigelow', 1)
# ('greenwich', 1)
# ('village', 1)
# ('helped', 1)
# ('heal', 1)
# ('manhattans', 1)
# ('ailing', 1)
# ('generations', 1)
# ('thanks', 1)
# ('single', 1)
# ('family', 1)
# ('8yearold', 1)
# ('threatened', 1)
# ('suicide', 1)
# ('learning', 1)
# ('troubled', 1)
# ('scary', 1)
# ('parenting', 1)
# ('moment', 1)
# ('mother', 1)
# ('talking', 1)
# ('experts', 1)
# ('son', 1)
# ('path', 1)
# ('healing', 1)
# ('advertisement', 1)
# ('wed', 1)
# ('home', 1)
# ('page', 1)
# ('experience', 1)
# ('information', 1)
# ('navigation', 1)
# ('2021', 1)
# ('company', 1)
# ('nytco', 1)
# ('contact', 1)
# ('accessibility', 1)
# ('advertise', 1)
# ('brand', 1)
# ('studio', 1)
# ('ad', 1)
# ('choices', 1)
# ('privacy', 1)
# ('policy', 1)
# ('service', 1)
# ('sale', 1)
# ('map', 1)
# ('help', 1)
# ('subscriptions', 1)
